# %%
import os
import pandas as pd
import numpy as np
from shutil import copyfile

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define PATH
folder_path = r'C:\Users\mosta\Downloads\Restaurant Consumer Data\restaurant+consumer+data'


for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        file_path = os.path.join(folder_path, file)
        try:
            if file == 'geoplaces2.csv':
                res_con = pd.read_csv(file_path, encoding='latin-1')
            else:
                res_con = pd.read_csv(file_path, encoding='utf-8')
            
            print(f"Contents of {file}:")
            display(res_con)  # Show CSV files (Total 8)
            #Throw error
        except Exception as e:
            print(f"An error occurred while reading {file}: {e}")
# Out:
# Contents of chefmozaccepts.csv:
#       placeID             Rpayment
# 0      135110                 cash
# 1      135110                 VISA
# 2      135110  MasterCard-Eurocard
# 3      135110     American_Express
# 4      135110     bank_debit_cards
# ...       ...                  ...
# 1309   132012          Diners_Club
# 1310   132002  MasterCard-Eurocard
# 1311   132002                 Visa
# 1312   132002     American_Express
# 1313   132002          Diners_Club
#
# [1314 rows x 2 columns]
# Contents of chefmozcuisine.csv:
#      placeID        Rcuisine
# 0     135110         Spanish
# 1     135109         Italian
# 2     135107  Latin_American
# 3     135106         Mexican
# 4     135105       Fast_Food
# ..       ...             ...
# 911   132005         Seafood
# 912   132004         Seafood
# 913   132003   International
# 914   132002         Seafood
# 915   132001   Dutch-Belgian
#
# [916 rows x 2 columns]
# Contents of chefmozhours4.csv:
# ...

# %%
file_path_geoplaces2 = r'C:\Users\mosta\Downloads\Restaurant Consumer Data\restaurant+consumer+data\geoplaces2.csv'
geoplaces2 = pd.read_csv(file_path_geoplaces2, encoding='latin1') #Using different encoding methods

columns_to_drop = ['url', 'fax']
geoplaces2 = geoplaces2.drop(columns=columns_to_drop, axis=1)

print(geoplaces2.head())
# Out:
#    placeID   latitude   longitude  \
# 0   134999  18.915421  -99.184871
# 1   132825  22.147392 -100.983092
# 2   135106  22.149709 -100.976093
# 3   132667  23.752697  -99.163359
# 4   132613  23.752903  -99.165076
#
#                                       the_geom_meter  \
# 0  0101000020957F000088568DE356715AC138C0A525FC46...
# 1  0101000020957F00001AD016568C4858C1243261274BA5...
# 2  0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3  0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4  0101000020957F00008EBA2D06DC8157C194E03B7B504E...
#
#                              name                                 address  \
# 0                 Kiku Cuernavaca                              Revolucion
# 1                 puesto de tacos  esquina santos degollado y leon guzman
# 2      El Rincón de San Francisco                         Universidad 169
# 3  little pizza Emilio Portes Gil                 calle emilio portes gil
# ...

# %%
file_path_userprofile = r'C:\Users\mosta\Downloads\Restaurant Consumer Data\restaurant+consumer+data\userprofile.csv'

userprofile = pd.read_csv(file_path_userprofile).drop(columns=['height', 'weight', 'color'])

print(userprofile.head())
# Out:
#   userID   latitude   longitude smoker     drink_level dress_preference  \
# 0  U1001  22.139997 -100.978803  false      abstemious         informal
# 1  U1002  22.150087 -100.983325  false      abstemious         informal
# 2  U1003  22.119847 -100.946527  false  social drinker           formal
# 3  U1004  18.867000  -99.183000  false      abstemious         informal
# 4  U1005  22.183477 -100.959891  false      abstemious    no preference
#
#   ambience transport marital_status       family  birth_year    interest  \
# 0   family   on foot         single  independent        1989     variety
# 1   family    public         single  independent        1990  technology
# 2   family    public         single  independent        1989        none
# 3   family    public         single  independent        1940     variety
# 4   family    public         single  independent        1992        none
#
#            personality  religion      activity  budget
# ...

# %%
csv_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.csv')]

for file_name in csv_files:
    file_path = os.path.join(folder_path, file_name)
    res_con = pd.read_csv(file_path, encoding='latin1')

res_con = res_con.rename(columns={'hijos': 'family'})

res_con.to_csv(file_path, index=False)

# %%
res_con = pd.read_csv(file_path, na_values='?')

missing_values = res_con.isnull().sum()

print("Columns with missing values:")
print(missing_values[missing_values > 0])
# Out:
# Columns with missing values:
# smoker               3
# dress_preference     5
# ambience             6
# transport            7
# marital_status       4
# family              11
# activity             7
# budget               7
# dtype: int64

# %%
missing_percentage = (res_con.isnull().sum() / len(res_con)) * 100

missing_values = pd.DataFrame({ 'Missing Percentage': missing_percentage})

print("Percentage of missing values in each column:")
print(missing_values)
# Out:
# Percentage of missing values in each column:
#                   Missing Percentage
# userID                      0.000000
# latitude                    0.000000
# longitude                   0.000000
# smoker                      2.173913
# drink_level                 0.000000
# dress_preference            3.623188
# ambience                    4.347826
# transport                   5.072464
# marital_status              2.898551
# family                      7.971014
# birth_year                  0.000000
# interest                    0.000000
# personality                 0.000000
# religion                    0.000000
# activity                    5.072464
# color                       0.000000
# weight                      0.000000
# budget                      5.072464
# height                      0.000000

# %%
res_con = res_con.dropna()
res_con.dropna(inplace=True)

# %%
missing_percentage = (res_con.isnull().sum() / len(res_con)) * 100

missing_values = pd.DataFrame({ 'Missing Percentage': missing_percentage})

print("Percentage of missing values in each column:")
print(missing_values)
# Out:
# Percentage of missing values in each column:
#                   Missing Percentage
# userID                           0.0
# latitude                         0.0
# longitude                        0.0
# smoker                           0.0
# drink_level                      0.0
# dress_preference                 0.0
# ambience                         0.0
# transport                        0.0
# marital_status                   0.0
# family                           0.0
# birth_year                       0.0
# interest                         0.0
# personality                      0.0
# religion                         0.0
# activity                         0.0
# color                            0.0
# weight                           0.0
# budget                           0.0
# height                           0.0

# %%
folder_path = r'C:\Users\mosta\Downloads\Restaurant Consumer Data\restaurant+consumer+data'
specific_files = ['chefmozaccepts.csv', 'chefmozcuisine.csv', 'chefmozhours4.csv', 'rating_final.csv']
data_frames = []


for file in specific_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    data_frames.append(df)
    
merged_data = pd.concat(data_frames, axis=1)
merged_data.to_csv('res_df.csv', index=False)

# %%
file_path = r'C:\Users\mosta\Downloads\Restaurant Consumer Data\restaurant+consumer+data\rating_final.csv'
rating_data = pd.read_csv(file_path)
display(rating_data)
# Out:
#      userID  placeID  rating  food_rating  service_rating
# 0     U1077   135085       2            2               2
# 1     U1077   135038       2            2               1
# 2     U1077   132825       2            2               2
# 3     U1077   135060       1            2               2
# 4     U1068   135104       1            1               2
# ...     ...      ...     ...          ...             ...
# 1156  U1043   132630       1            1               1
# 1157  U1011   132715       1            1               0
# 1158  U1068   132733       1            1               0
# 1159  U1068   132594       1            1               1
# 1160  U1068   132660       0            0               0
#
# [1161 rows x 5 columns]

# %%
res_df = pd.read_csv('res_df.csv')
display(res_df)
# Out:
#        placeID             Rpayment  placeID.1        Rcuisine  placeID.2  \
# 0     135110.0                 cash   135110.0         Spanish     135111
# 1     135110.0                 VISA   135109.0         Italian     135111
# 2     135110.0  MasterCard-Eurocard   135107.0  Latin_American     135111
# 3     135110.0     American_Express   135106.0         Mexican     135110
# 4     135110.0     bank_debit_cards   135105.0       Fast_Food     135110
# ...        ...                  ...        ...             ...        ...
# 2334       NaN                  NaN        NaN             NaN     132012
# 2335       NaN                  NaN        NaN             NaN     132012
# 2336       NaN                  NaN        NaN             NaN     132012
# 2337       NaN                  NaN        NaN             NaN     132012
# 2338       NaN                  NaN        NaN             NaN     132012
#
#              hours                  days userID  placeID.3  rating  \
# ...

# %%
change_color = sns.color_palette("Oranges_r", len(res_df['Rcuisine'].unique()))


plt.figure(figsize=(12, 6))
sns.barplot(x='Rcuisine', y='rating', data=res_df, errorbar=None, palette=change_color)
plt.title('Average Rating by Cuisine Type')
plt.xlabel('Cuisine Type')
plt.ylabel('Average Rating on Scale of 0 - 2')
plt.xticks(rotation=90)
plt.show()

# %%
folder_path = r'C:\Users\mosta\Downloads\Restaurant Consumer Data\restaurant+consumer+data'
specific_files = ['usercuisine.csv', 'userpayment.csv', 'userprofile.csv', 'rating_final.csv']
data_frames = []


for file in specific_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    data_frames.append(df)
    
merged_data = pd.concat(data_frames, axis=1)
merged_data.to_csv('con_df.csv', index=False)

# %%
con_df = pd.read_csv('con_df.csv')
con_df = con_df.drop(columns=['height', 'weight', 'color'])
display(con_df)
# Out:
#      userID          Rcuisine userID.1          Upayment userID.2   latitude  \
# 0     U1001          American    U1001              cash    U1001  22.139997
# 1     U1002           Mexican    U1002              cash    U1002  22.150087
# 2     U1003           Mexican    U1003              cash    U1003  22.119847
# 3     U1004            Bakery    U1004              cash    U1004  18.867000
# 4     U1004  Breakfast-Brunch    U1004  bank_debit_cards    U1005  22.183477
# ...     ...               ...      ...               ...      ...        ...
# 1156    NaN               NaN      NaN               NaN      NaN        NaN
# 1157    NaN               NaN      NaN               NaN      NaN        NaN
# 1158    NaN               NaN      NaN               NaN      NaN        NaN
# 1159    NaN               NaN      NaN               NaN      NaN        NaN
# 1160    NaN               NaN      NaN               NaN      NaN        NaN
#
# ...

# %%
encoded_columns = pd.get_dummies(con_df[['activity', 'budget']])

# %%
modified_df = pd.concat([con_df[['rating']], encoded_columns], axis=1)

# %%
file_path = r'C:\Users\mosta\Downloads\Restaurant Consumer Data\con_df.csv'
ratingcon_df = pd.read_csv(file_path)
print(ratingcon_df.head())
# Out:
#   userID          Rcuisine userID.1          Upayment userID.2   latitude  \
# 0  U1001          American    U1001              cash    U1001  22.139997
# 1  U1002           Mexican    U1002              cash    U1002  22.150087
# 2  U1003           Mexican    U1003              cash    U1003  22.119847
# 3  U1004            Bakery    U1004              cash    U1004  18.867000
# 4  U1004  Breakfast-Brunch    U1004  bank_debit_cards    U1005  22.183477
#
#     longitude smoker     drink_level dress_preference  ...      activity  \
# 0 -100.978803  false      abstemious         informal  ...       student
# 1 -100.983325  false      abstemious         informal  ...       student
# 2 -100.946527  false  social drinker           formal  ...       student
# 3  -99.183000  false      abstemious         informal  ...  professional
# 4 -100.959891  false      abstemious    no preference  ...       student
#
#    color weight  budget  height userID.3 placeID rating food_rating  \
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(modified_df.corr(), annot=True, cmap='Oranges')
plt.title('Correlation Heatmap')
plt.show()

# %%
encoded_activity = pd.get_dummies(con_df['activity'])
activity_df = pd.concat([con_df['rating'], encoded_activity], axis=1)
plt.figure(figsize=(6, 4))
sns.heatmap(activity_df.corr(), annot=True, cmap='Oranges')
plt.title('Correlation Heatmap for Activity')
plt.show()

# %%
encoded_budget = pd.get_dummies(con_df['budget'])
budget_df = pd.concat([con_df['rating'], encoded_budget], axis=1)
plt.figure(figsize=(6, 4))
sns.heatmap(budget_df.corr(), annot=True, cmap='Oranges')
plt.title('Correlation Heatmap for Budget')
plt.show()

# %% [markdown]
# Content-based filtering

# %%
display(res_df)
# Out:
#        placeID             Rpayment  placeID.1        Rcuisine  placeID.2  \
# 0     135110.0                 cash   135110.0         Spanish     135111
# 1     135110.0                 VISA   135109.0         Italian     135111
# 2     135110.0  MasterCard-Eurocard   135107.0  Latin_American     135111
# 3     135110.0     American_Express   135106.0         Mexican     135110
# 4     135110.0     bank_debit_cards   135105.0       Fast_Food     135110
# ...        ...                  ...        ...             ...        ...
# 2334       NaN                  NaN        NaN             NaN     132012
# 2335       NaN                  NaN        NaN             NaN     132012
# 2336       NaN                  NaN        NaN             NaN     132012
# 2337       NaN                  NaN        NaN             NaN     132012
# 2338       NaN                  NaN        NaN             NaN     132012
#
#              hours                  days userID  placeID.3  rating  \
# ...
